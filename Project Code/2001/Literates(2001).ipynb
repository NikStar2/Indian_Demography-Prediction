# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
df=pd.read_csv("/content/census_2001_sw.csv")
df
# Out:
#     S.NO                       State  ...  Graduate  Total_workers
# 0      1   Andaman & Nicobar Islands  ...     14903         136254
# 1      2                      Andhra  ...   2672346       32953645
# 2      3            ArunachalPradesh  ...     26047         482902
# 3      4                       Assam  ...    678887        9538591
# 4      5                       Bihar  ...   2109415       27974606
# 5      6                Chhattisgarh  ...    576721        9679871
# 6      7                  Chandigarh  ...    138441         340422
# 7      8                 Daman & Diu  ...      6209          72791
# 8      9                       Delhi  ...   1761915        4545234
# 9     10        Dadra & Nagar Haveli  ...      7896         114122
# 10    11                         Goa  ...     98297         522855
# 11    12                     Gujarat  ...   1875741       21255521
# 12    13                     Haryana  ...    798689        8377466
# 13    14            Himachal Pradesh  ...    220770        2992461
# 14    15                   Jharkhand  ...    808678       10109030
# 15    16             Jammu & Kashmir  ...    331548        3753815
# 16    17                   Karnataka  ...   2098294       23534791
# 17    18                      Kerala  ...   1443049       10283887
# 18    19                  Lakshdweep  ...       959          15354
# 19    20                 Maharashtra  ...   4886347       41173351
# 20    21                     Manipur  ...    142798         873325
# 21    22                    Meghalya  ...     51642         970146
# 22    23                     Mizoram  ...     26419         467159
# 23    24              Madhya Pradesh  ...   1931049       25793519
# 24    25                    Nagaland  ...     57511         847796
# 25    26                      Orrisa  ...   1147895       13822918
# 26    27                 Pondicherry  ...     68364         342655
# 27    28                      Punjab  ...    966747        9127474
# 28    29                   Rajasthan  ...   1471813       23766655
# 29    30                      Sikkim  ...     14348         263043
# 30    31                  Tamil Nadu  ...   2196698       27878282
# 31    32                     Tripura  ...     99850        1159561
# 32    33               Uttar Pradesh  ...   4969397       53983824
# 33    34                  Uttranchal  ...    460155        3134036
# 34    35                West Bengal   ...   3186374       29481690
#
# [35 rows x 13 columns]

# %%
fig_size = plt.rcParams["figure.figsize"]
fig_size[0] = 20
fig_size[1] = 10
plt.rcParams["figure.figsize"] = fig_size

# %% [markdown]
# Male Literates in each State

# %%
plt.bar(df.State[0:10],df.Males_Literate[0:10])
plt.xlabel("State")
plt.ylabel("Population of Male Literates in each state")
plt.xticks(rotation=45)
plt.savefig("MLimg1.jpg")

# %%
plt.bar(df.State[10:20],df.Males_Literate[10:20])
plt.xlabel("State")
plt.ylabel("Population of Male Literates in each state")
plt.xticks(rotation=45)
plt.savefig("MLimg2.jpg")

# %%
plt.bar(df.State[20:30],df.Males_Literate[20:30])
plt.xlabel("State")
plt.ylabel("Population of Male Literates in each state")
plt.xticks(rotation=45)
plt.savefig("MLimg3.jpg")

# %%
plt.bar(df.State[30:36],df.Males_Literate[30:36])
plt.xlabel("State")
plt.ylabel("Population of Male Literates in each state")
plt.xticks(rotation=45)
plt.savefig("MLimg4.jpg")

# %% [markdown]
# Female Literates in each State

# %%
plt.bar(df.State[0:10],df.Females_Literate[0:10])
plt.xlabel("State")
plt.ylabel("Population of Male Literates in each state")
plt.xticks(rotation=45)
plt.savefig("fLimg1.jpg")

# %%
plt.bar(df.State[10:20],df.Females_Literate[10:20])
plt.xlabel("State")
plt.ylabel("Population of Male Literates in each state")
plt.xticks(rotation=45)
plt.savefig("fLimg2.jpg")

# %%
plt.bar(df.State[20:30],df.Females_Literate[20:30])
plt.xlabel("State")
plt.ylabel("Population of Male Literates in each state")
plt.xticks(rotation=45)
plt.savefig("fLimg3.jpg")

# %%
plt.bar(df.State[30:36],df.Females_Literate[30:36])
plt.xlabel("State")
plt.ylabel("Population of Male Literates in each state")
plt.xticks(rotation=45)
plt.savefig("fLimg4.jpg")

# %% [markdown]
# Graduate in each State

# %%
plt.bar(df.State[0:10],df.Graduate[0:10])
plt.xlabel("State")
plt.ylabel("Population of Graduates in each state")
plt.xticks(rotation=45)
plt.savefig("Gimg1.jpg")

# %%
plt.bar(df.State[10:20],df.Graduate[10:20])
plt.xlabel("State")
plt.ylabel("Population of Graduates in each state")
plt.xticks(rotation=45)
plt.savefig("Gimg2.jpg")

# %%
plt.bar(df.State[20:30],df.Graduate[20:30])
plt.xlabel("State")
plt.ylabel("Population of Graduates in each state")
plt.xticks(rotation=45)
plt.savefig("Gimg3.jpg")

# %%
plt.bar(df.State[30:36],df.Graduate[30:36])
plt.xlabel("State")
plt.ylabel("Population of Graduates in each state")
plt.xticks(rotation=45)
plt.savefig("Gimg4.jpg")
